# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import glob
from collections import Counter
import math
import re
import json
import subprocess
import time
import pickle

import pandas as pd
import umap
from tqdm.autonotebook import tqdm, trange
from nltk.tokenize import word_tokenize

import numpy as np
import scipy.stats
from sklearn.datasets import load_iris, load_digits
from sklearn.model_selection import train_test_split, KFold

from sklearn.preprocessing import LabelBinarizer, LabelEncoder
from sklearn.metrics import confusion_matrix, roc_auc_score, f1_score
from sklearn.utils import class_weight

from tensorflow import keras

import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
#assert gpus
try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)

    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)


import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelBinarizer, LabelEncoder
from sklearn.metrics import confusion_matrix
from sklearn.utils import class_weight
layers = keras.layers
models = keras.models
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K
import numpy.random as rng
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import ModelCheckpoint

import convert_model

import language
import text_nn
import grab_category
import news
import groups
import libs.cpp_stuff as cpp

# %%
lang = "en"
train_folders = [os.path.join("data", folder) for folder in ["sample", "sample2", "sample3", "sample4", "sample5", "sample6"]]
file_info = []
for folder in train_folders:
    file_info.extend(language.read_dump(f"{folder}/langs/{lang}"))

# %%
cities_data = pd.read_excel("data/WUP2018-F12-Cities_Over_300K.xls", skiprows=16)
geo_to_country = dict(zip(cities_data["Urban Agglomeration"], cities_data["Country or area"]))
for geo, country in geo_to_country.items():
    if "(" in country:
        country = country.split(" (")[0]
    
    geo_to_country[geo] = country
    
geo_to_country["USA"] = 'United States of America'
geo_to_country["United States"] = 'United States of America'
geo_to_country["U.S."] = 'United States of America'
geo_to_country["New York"] = 'United States of America'
geo_to_country["UK"] = 'United Kingdom'
geo_to_country["Bosnia"] = 'Bosnia and Herzegovina'
geo_to_country["Hong Kong"] = 'China, Hong Kong SAR'
geo_to_country["Macao"] = 'China, Macao SAR'
geo_to_country["Taiwan"] = 'China, Taiwan Province of China'
geo_to_country["Russia"] = 'Russian Federation'
geo_to_country["Syria"] = 'Syrian Arab Republic'
geo_to_country["Vietnam"] = 'Viet Nam'
geo_to_country["crore"] = 'India'

for country in list(geo_to_country.values()):
    geo_to_country[country] = country

for geo, country in list(geo_to_country.items()):
    if "(" in geo:
        del geo_to_country[geo]
        geo1 = geo.split("(")[0].strip()
        geo_to_country[geo1] = country
        geo2 = geo.split("(")[1].replace(")", "").replace("incl. ", "").replace("including ", "")
        geo_to_country[geo2] = country
        
    if ", " in geo and "China" not in geo:
        del geo_to_country[geo]
        for n in geo.split(", "):
            geo_to_country[n] = country     
            
for geo in ["Van", "Tours"]:
    del geo_to_country[geo]

# %%
country_regex = {c: "" for c in geo_to_country.values()}
for geo, country in geo_to_country.items():
    if geo[-1] == ".":
        geo = geo[:-1]
        
    country_regex[country] += "|" + geo
    
for country, regex in country_regex.items():
    country_regex[country] = re.compile(r"\b(" + regex[1:].replace(".", "\.") + r")n?\b", re.IGNORECASE)
    
country_regex
# Out:
# {'Afghanistan': re.compile(r'\b(Herat|Kabul|Kandahar|Mazar-e Sharif|Afghanistan)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Algeria': re.compile(r'\b(Annaba|Batna|Blida|El Djelfa|Qacentina|Sétif|Algeria|El Djazaïr|Algiers|Wahran|Oran)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Angola': re.compile(r'\b(Benguela|Cabinda|Cuito|Huambo|Lobito|Luanda|Lubango|Malanje|Uige|Angola)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Argentina': re.compile(r'\b(Bahia Blanca|Buenos Aires|Corrientes|La Plata|Mar Del Plata|Mendoza|Neuquén-Plottier-Cipolletti|Posadas|Resistencia|Rosario|Salta|San Miguel de Tucumán|San Salvador de Jujuy|Santa Fe|Santiago Del Estero|Argentina)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Mexico': re.compile(r'\b(Córdoba|Acapulco de Juárez|Aguascalientes|Cancún|Celaya|Chihuahua|Ciudad Juárez|Ciudad Obregón|Ciudad Victoria|Coatzacoalcos|Colima|Cuautla Morelos|Cuernavaca|Culiacán|Durango|Ensenada|Guadalajara|Hermosillo|Irapuato|La Laguna|León de los Aldamas|Los Mochis|Matamoros|Mazatlán|Mérida|Mexicali|Minatitlán|Monclova|Monterrey|Morelia|Nuevo Laredo|Oaxaca de Juárez|Orizaba|Pachuca de Soto|Poza Rica de Hidalgo|Puebla|Puerto Vallarta|Querétaro|Reynosa|Saltillo|San Luis Potosí|Tampico|Tehuacán|Tepic|Tijuana|Tlaxcala|Toluca de Lerdo|Tuxtla Gutierrez|Uruapán|Veracruz|Villahermosa|Xalapa|Zacatecas|Mexico|Ciudad de México|Mexico City)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Puerto Rico': re.compile(r'\b(San Juan|Aguadilla-Isabela-San Sebastian|Puerto Rico)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Armenia': re.compile(r'\b(Yerevan|Armenia)n?\b', re.IGNORECASE|re.UNICODE),
#  'Australia': re.compile(r'\b(Adelaide|Brisbane|Canberra|Central Coast|Gold Coast-Tweed Head|Melbourne|Newcastle-Maitland|Perth|Sunshine Coast|Sydney|Wollongong|Australia)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Azerbaijan': re.compile(r'\b(Baku|Gäncä|Sumquayit|Azerbaijan)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Bangladesh': re.compile(r'\b(Barisal|Bogra|Chittagong|Comilla|Dhaka|Khulna|Mymensingh|Rajshahi|Rangpur|Rupganj|Sylhet|Bangladesh)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Belarus': re.compile(r'\b(Brest|Gomel|Grodno|Minsk|Mogilev|Vitebsk|Belarus)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Belgium': re.compile(r'\b(Antwerpen|Bruxelles-Brussel|Charleroi|Gent|Liège|Belgium)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Benin': re.compile(r'\b(Abomey-Calavi|Cotonou|Djougou|Parakou|Benin)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Bolivia': re.compile(r'\b(Cochabamba|La Paz|Oruro|Santa Cruz|Bolivia)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Bosnia and Herzegovina': re.compile(r'\b(Sarajevo|Bosnia|Bosnia and Herzegovina)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Brazil': re.compile(r'\b(Anápolis|Aracaju|Baixada Santista|Bauru|Belém|Belo Horizonte|Blumenau|Boa Vista|Brasília|Campina Grande|Campinas|Campo Grande|Campos dos Goytacazes|Caruaru|Cascavel|Caxias Do Sul|Cuiabá|Curitiba|Feira De Santana|Florianópolis|Fortaleza|Franca|Goiânia|Grande São Luís|Grande Vitória|João Pessoa|Joinville|Juazeiro Do Norte|Juiz De Fora|Jundiaí|Londrina|Macapá|Maceió|Manaus|Maringá|Montes Claros|Natal|Pelotas|Petrolina|Piracicaba|Ponta Grossa|Pôrto Alegre|Pôrto Velho|Recife|Ribeirão  Preto|Rio Branco|Rio de Janeiro|Salvador|São José do Rio Preto|São José dos Campos|São Paulo|Sorocaba|Taubaté|Teresina|Uberaba|Uberlândia|Vale do Aço|Vitória da Conquista|Volta Redonda|Brazil)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Bulgaria': re.compile(r'\b(Plovdiv|Sofia|Varna|Bulgaria)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Burkina Faso': re.compile(r'\b(Bobo-Dioulasso|Ouagadougou|Burkina Faso)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  '
#  re.IGNORECASE|re.UNICODE),
#  'Republic of Korea': re.compile(r'\b(Anyang|Ansan|Bucheon|Busan|Changwon|Cheonan|Cheongju|Daegu|Daejon|Gimhae|Goyang|Gumi|Gwangju|Gwangmyeong|Incheon|Jeju|Jeonju|Pohang|Seongnam|Seoul|Siheung|Suweon|Uijeongbu|Ulsan|Yongin|Republic of Korea)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'China, Hong Kong SAR': re.compile(r'\b(Hong Kong|China, Hong Kong SAR)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'China, Macao SAR': re.compile(r'\b(Macao|China, Macao SAR)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'China, Taiwan Province of China': re.compile(r'\b(Gaoxiong|Jilong|Taibei|Tainan|Taizhong|Taoyuan|Xinbei|Xinzhu|Taiwan|China, Taiwan Province of China)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Colombia': re.compile(r'\b(Barranquilla|Bogotá|Bucaramanga|Buenaventura|Cali|Cartagena|Cúcuta|Ibagué|Manizales|Medellín|Monteria|Neiva|Pasto|Pereira|Santa Marta|Valledupar|Villavicencio|Colombia)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Congo': re.compile(r'\b(Brazzaville|Pointe-Noire|Congo)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Costa Rica': re.compile(r'\b(Alajuela|Heredia|San José|Costa Rica)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  "Côte d'Ivoire": re.compile(r"\b(Abidjan|Bouake|Côte d'Ivoire)n?\b",
#  re.IGNORECASE|re.UNICODE),
#  'Croatia': re.compile(r'\b(Zagreb|Croatia)n?\b', re.IGNORECASE|re.UNICODE),
#  'Cuba': re.compile(r'\b(Camaguey|Santiago de Cuba|Cuba|La Habana|Havana)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Czechia': re.compile(r'\b(Brno|Czechia|Praha|Prague)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  "Dem. People's Republic of Korea": re.compile(r"\b(Chongjin|Hamhung|P'yongyang|Sinuiju|Wonsan|Dem\. People's Republic of Korea)n?\b",
#  re.IGNORECASE|re.UNICODE),
#  'Democratic Republic of the Congo': re.compile(r'\b(Bukavu|Bunia|Goma|Kabinda|Kananga|Kikwit|Kinshasa|Kisangani|Kolwezi|Likasi|Lubumbashi|Matadi|Mbandaka|Mbuji-Mayi|Tshikapa|Uvira|Democratic Republic of the Congo)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Djibouti': re.compile(r'\b(Djibouti)n?\b', re.IGNORECASE|re.UNICODE),
#  'Ecuador': re.compile(r'\b(Santo Domingo|Cuenca|Guayaquil|Quito|Ecuador)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Egypt': re.compile(r"\b(Al-Fayyum|Al-Ismailiyah|Al-Mahallah al-Kubra|Al-Mansurah|As-Suways|Aswan|Asyut|Az-Zaqazig|Bur Sa'id|Kafr-ad-Dawwar|Tanta|Egypt|Al-Iskandariyah|Alexandria|Al-Qahirah|Cairo)n?\b",
#  re.IGNORECASE|re.UNICODE),
#  'El Salvador': re.compile(r'\b(San Salvador|El Salvador)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Equatorial Guinea': re.compile(r'\b(Bata|Equatorial Guinea)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Eritrea': re.compile(r'\b(Asmara|Eritrea)n?\b', re.IGNORECASE|re.UNICODE),
#  'Estonia': re.compile(r'\b(Tallinn|Estonia)n?\b', re.IGNORECASE|re.UNICODE),
#  'Ethiopia': re.compile(r'\b(Addis Ababa|Dire Dawa|Gondar|Mekele|Nazret|Ethiopia)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Finland': re.compile(r'\b(Helsinki|Tampere|Finland)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'France': re.compile(r'\b(Avignon|Béthune|Bordeaux|Douai-Lens|Grenoble|Lille|Lyon|Marseille-Aix-en-Provence|Montpellier|Nantes|Nice-Cannes|Paris|Rennes|Rouen|Saint-Étienne|Strasbourg|Toulon|Toulouse|Valenciennes|France)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Gabon': re.compile(r'\b(Libreville|Gabon)n?\b', re.IGNORECASE|re.UNICODE),
#  'Gambia': re.compile(r'\b(Banjul|Gambia)n?\b', re.IGNORECASE|re.UNICODE),
#  'Georgia': re.compile(r'\b(Tbilisi|Georgia)n?\b', re.IGNORECASE|re.UNICODE),
#  'Germany': re.compile(r'\b(Berlin|Bielefeld|Bochum|Bonn|Bremen|Dortmund|Dresden|Duesseldorf|Duisburg|Essen|Frankfurt am Main|Hamburg|Hannover|Karlsruhe|Leipzig|Mannheim|Nurenberg|Stuttgart|Wuppertal|Germany|Köln|Cologne|Muenster|Westfalen|München|Munich)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Ghana': re.compile(r'\b(Accra|Kumasi|Sekondi Takoradi|Tamale|Ghana)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Greece': re.compile(r'\b(Thessaloniki|Greece|Athínai|Athens)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Guinea': re.compile(r'\b(Conakry|Guinea)n?\b', re.IGNORECASE|re.UNICODE),
#  'Guinea-Bissau': re.compile(r'\b(Bissau|Guinea-Bissau)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Haiti': re.compile(r'\b(Port-au-Prince|Haiti)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Honduras': re.compile(r'\b(San Pedro Sula|Tegucigalpa|Honduras)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Hungary': re.compile(r'\b(Budapest|Hungary)n?\b', re.IGNORECASE|re.UNICODE),
#  'India': re.compile(r'\b(Agartala|Agra|Ahmadabad|Ahmadnagar|Aizawl|Ajmer|Akola|Aligarh|Allahabad|Alwar|Amravati|Amritsar|Anand|Anantapur|Arrah|Asansol|Aurangabad|Baharampur|Bangalore|Barddhaman|Bareilly|Bathinda|Begusarai|Belgaum|Bellary|Bhagalpur|Bhavnagar|Bhilwara|Bhiwandi|Bhopal|Bhubaneswar|Bihar Sharif|Bijapur|Bikaner|Bilaspur|Bokaro Steel City|Brahmapur|Chandigarh|Chandrapur|Cherthala|Coimbatore|Cuttack|Darbhanga|Davanagere|Dehradun|Delhi|Deoghar|Dewas|Dhanbad|Dhule|Dhulian|Dindigul|Durgapur|Durg-Bhilainagar|English Bazar|Erode|Farrukhabad|Firozabad|Gandhidham|Gaya|Gorakhpur|Gulbarga|Guntur|Gwalior|Habra|Haldwani-cum-kathgodam|Hapur|Hardwar|Hisar|Hosur|Hubli-Dharwad|Ichalkaranji|Imphal|Indore|Jabalpur|Jaipur|Jalandhar|Jalgaon|Jalna|Jammu|Jamnagar|Jamshedpur|Jhansi|Jodhpur|Junagadh|Kadapa|Kakinada|Kanhangad|Kannur|Kanpur|Karimnagar|Karnal|Karur|Kayamkulam|Khammam|Kharagpur|Kolhapur|Kollam|Korba|Kota|Kottayam|Kurnool|Latur|Lucknow|Ludhiana|Mad
n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Jamaica': re.compile(r'\b(Kingston|Jamaica)n?\b', re.IGNORECASE|re.UNICODE),
#  'Japan': re.compile(r'\b(Akita|Asahikawa|Fukuyama|Hiroshima|Iwaki|Kagoshima|Kanazawa|Kitakyushu-Fukuoka M\.M\.A|Koriyama|Kumamoto|Kurashiki|Kurume|Maebashi|Matsuyama|Miyazaki|Nagano|Nagasaki|Naha|Niigata|Oita|Okayama|Sapporo|Sendai|Shizuoka-Hamamatsu M\.M\.A|Takamatsu|Takasaki|Tokyo|Toyama|Toyohashi|Utsunomiya|Japan|Chukyo M\.M\.A|Nagoya|Kinki M\.M\.A|Osaka)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Jordan': re.compile(r'\b(Al-Quwaysimah|Amman|Ar-Rusayfah|Irbid|Tila al-Ali|Zarqa|Jordan)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Kazakhstan': re.compile(r'\b(Aktyubinsk|Almaty|Astana|Karaganda|Pavlodar|Semipalatinsk|Shimkent|Taraz|Ust-Kamenogorsk|Kazakhstan)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Kenya': re.compile(r'\b(Eldoret|Kisumu|Mombasa|Nairobi|Nakuru|Ruiru|Kenya)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Kyrgyzstan': re.compile(r'\b(Bishkek|Kyrgyzstan)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  "Lao People's Democratic Republic": re.compile(r"\b(Vientiane|Lao People's Democratic Republic)n?\b",
#  re.IGNORECASE|re.UNICODE),
#  'Latvia': re.compile(r'\b(Riga|Latvia)n?\b', re.IGNORECASE|re.UNICODE),
#  'Liberia': re.compile(r'\b(Monrovia|Liberia)n?\b', re.IGNORECASE|re.UNICODE),
#  'Libya': re.compile(r'\b(Banghazi|Misratah|Libya|Tarabulus|Tripoli)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Lithuania': re.compile(r'\b(Vilnius|Lithuania)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Madagascar': re.compile(r'\b(Antananarivo|Antsirabe|Toamasina|Madagascar)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Malawi': re.compile(r'\b(Blantyre-Limbe|Lilongwe|Malawi)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Malaysia': re.compile(r'\b(Alor Star|Ipoh|Johor Bahru|Kota Bharu|Kota Kinabalu|Kuala Lumpur|Kuala Terengganu|Kuantan|Kuching|Sandakan|Seremban|Malaysia)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Mali': re.compile(r'\b(Bamako|Sikasso|Mali)n?\b', re.IGNORECASE|re.UNICODE),
#  'Mauritania': re.compile(r'\b(Nouakchott|Mauritania)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Mongolia': re.compile(r'\b(Ulaanbaatar|Mongolia)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Morocco': re.compile(r'\b(Agadir|Fès|Kénitra|Marrakech|Meknès|Oujda|Rabat|Safi|Tanger|Tétouan|Morocco|Dar-el-Beida|Casablanca)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Mozambique': re.compile(r'\b(Beira|Chimoio|Maputo|Matola|Nampula|Quelimane|Tete|Mozambique)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Myanmar': re.compile(r'\b(Mandalay|Nay Pyi Taw|Yangon|Myanmar)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Namibia': re.compile(r'\b(Windhoek|Namibia)n?\b', re.IGNORECASE|re.UNICODE),
#  'Nepal': re.compile(r'\b(Kathmandu|Pokhara|Nepal)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Netherlands': re.compile(r'\b(Amsterdam|Eindhoven|Rotterdam|Utrecht|Netherlands|s-Gravenhage|The Hague)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'New Zealand': re.compile(r'\b(Auckland|Christchurch|Wellington|New Zealand)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Nicaragua': re.compile(r'\b(Managua|Nicaragua)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  '
beach-McHenry-Grayslake|Sacramento|Salt Lake City|San Antonio|San Diego|San Francisco-Oakland|San Jose|Santa Clarita|Sarasota-Bradenton|Savannah|Scranton|Seattle|Shreveport|Spokane|St\. Louis|Stockton|Syracuse|Tampa-St\. Petersburg|Temecula-Murrieta|The Woodlands|Toledo|Trenton|Tucson|Tulsa|Victorville-Hesperia-Apple Valley|Virginia Beach|Visalia|Wichita|Winston-Salem|Worcester|Youngstown|USA|United States|U\.S|New York|United States of America|Columbia|South Carolina|Columbus|Ohio|Jackson|Mississippi|Jacksonville|Florida|Springfield|Massachusett|Connecticut|Missouri|Washington|D\.C)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Poland': re.compile(r'\b(Bydgoszcz|Gdańsk|Łódź|Lublin|Poznań|Szczecin|Wrocław|Poland|Kraków|Cracow|Warszawa|Warsaw)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Portugal': re.compile(r'\b(Porto|Portugal|Lisboa|Lisbon)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Qatar': re.compile(r'\b(Ar-Rayyan|Doha Industrial Area|Qatar|Ad-Dawhah|Doha)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Republic of Moldova': re.compile(r'\b(Chişinău|Republic of Moldova)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Romania': re.compile(r'\b(Cluj-Napoca|Iasi|Timisoara|Romania|Bucuresti|Bucharest)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Russian Federation': re.compile(r'\b(Arkhangelsk|Astrakhan|Balashikha|Barnaul|Belgorod|Bryansk|Cheboksary|Chelyabinsk|Cherepovets|Chita|Irkutsk|Ivanovo|Izhevsk|Kaluga|Kazan|Kemerovo|Khabarovsk|Kirov|Krasnodar|Krasnoyarsk|Kurgan|Kursk|Lipetsk|Magnitogorsk|Makhachkala|Naberezhnye Tchelny|Nizhniy Novgorod|Nizhny Tagil|Novokuznetsk|Novosibirsk|Omsk|Orel|Orenburg|Penza|Perm|Podolsk|Ryazan|Samara|Saransk|Saratov|Smolensk|Sochi|Stavropol|Surgut|Tolyatti|Tomsk|Tula|Tver|Tyumen|Ufa|Ulan-Ude|Ulyanovsk|Vladikavkaz|Vladimir|Vladivostok|Volgograd|Vologda|Volzhsky|Voronezh|Yakutsk|Yaroslavl|Yekaterinburg|Russia|Russian Federation|Kaliningrad|Kaliningrad Oblast|Moskva|Moscow|Rostov-na-Donu|Rostov-on-Don|Sankt Peterburg|Saint Petersburg)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Rwanda': re.compile(r'\b(Kigali|Rwanda)n?\b', re.IGNORECASE|re.UNICODE),
#  'Saudi Arabia': re.compile(r"\b(Ad-Dammam|Buraydah|Hafar al-Batin|Ha'il|Hufuf-Mubarraz|Jiddah|Jubayl|Khamis Mushayt|Khubar|Najran|Tabuk|Taif|Thuqbah|Yanbu' al-Bahr|Saudi Arabia|Al-Madinah|Medina|Ar-Riyadh|Riyadh|Makkah|Mecca)n?\b",
#  re.IGNORECASE|re.UNICODE),
#  'Senegal': re.compile(r'\b(Dakar|Rufisque|Thies|Senegal)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Sierra Leone': re.compile(r'\b(Freetown|Sierra Leone)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Singapore': re.compile(r'\b(Singapore)n?\b', re.IGNORECASE|re.UNICODE),
#  'Slovakia': re.compile(r'\b(Bratislava|Slovakia)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Somalia': re.compile(r'\b(Berbera|Hargeysa|Kismaayo|Merca|Somalia|Muqdisho|Mogadishu)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'South Africa': re.compile(r'\b(Bloemfontein|Cape Town|Ekurhuleni|Johannesburg|Polokwane|Pretoria|Rustenburg|Soshanguve|Vereeniging|West Rand|Witbank|South Africa|Durban|Ethekwini|East London|Buffalo City|Pietermaritzburg|The Msunduzi|Port Elizabeth|Nelson Mandela Bay)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'South Sudan': re.compile(r'\b(Juba|South Sudan)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Spain': re.compile(r'\b(Alicante|Barcelona|Bilbao|Cordoba|Las Palmas Gran Canaria|Madrid|Malaga|Murcia|Palma|Sevilla|Valladolid|Vigo|Zaragoza|Spain)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Venezuela': re.compile(r'\b(Valencia|Acarigua-Aruare|Barcelona-Puerto La Cruz|Barinas|Barquisimeto|Cabimas|Caracas|Ciudad Bolivar|Ciudad Guayana|Cumana|Guarenas-Guatire|Maracaibo|Maracay|Maturin|Merida|San Cristóbal|Venezuela)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Sri Lanka': re.compile(r'\b(Colombo|Sri Lanka)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Sudan': re.compile(r'\b(Al Gadarif|Kassala|Nyala|Wad Medani|Sudan|Al Obeid|Al Ubayyid|Al-Khartum|Khartoum|Port Sudan|Bur Sudan)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Sweden': re.compile(r'\b(Göteborg|Malmö|Stockholm|Sweden)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Switzerland': re.compile(r'\b(Basel|Bern|Genève|Lausanne|Switzerland|Zürich|Zurich)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Syrian Arab Republic': re.compile(r'\b(Al-Hasakah|Al-Raqqa|Hamah|Lattakia|Tartus|Syria|Syrian Arab Republic|Deir El-Zor|Deir ez-Zor|Dimashq|Damascus|Halab|Aleppo|Hims|Homs)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Tajikistan': re.compile(r'\b(Dushanbe|Tajikistan)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'TFYR Macedonia': re.compile(r'\b(Skopje|TFYR Macedonia)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Thailand': re.compile(r'\b(Buri Ram|Chanthaburi|Chiang Mai|Chiang Rai|Chon Buri|Kalasin|Khon-Kaen|Lampang|Lamphun|Lop Buri|Nakhon Pathom|Nakhon Ratchasima|Nonthaburi|Pathum Thani|Phra Nakhon Si Ayutthaya|Phuket|Ratchaburi|Rayong|Roi Et|Sakon Nakhon|Samut Prakan|Samut Sakhon|Songkhla|Suphan Buri|Surat Thani|Ubon Ratchathani|Udon Thani|Thailand|Krung Thep|Bangkok)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Togo': re.compile(r'\b(Lomé|Togo)n?\b', re.IGNORECASE|re.UNICODE),
#  'Trinidad and Tobago': re.compile(r'\b(Port of Spain|Trinidad and Tobago)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Tunisia': re.compile(r'\b(Safaqis|Tunis|Tunisia)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Turkey': re.compile(r'\b(Adana|Ankara|Antalya|Balikesir|Batman|Bursa|Denizli|Diyarbakir|Elazig|Erzurum|Eskisehir|Gaziantep|Gebze|Istanbul|Izmir|Izmit|Kahramanmaras|Kayseri|Konya|Malatya|Manisa|Mersin|Sakarya|Samsun|Sanliurfa|Sivas|Turkey)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Turkmenistan': re.compile(r'\b(Ashgabat|Turkmenistan)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Uganda': re.compile(r'\b(Kampala|Uganda)n?\b', re.IGNORECASE|re.UNICODE),
#  'Ukraine': re.compile(r'\b(Dnipro|Donetsk|Kharkiv|Kryvyi Rih|Luhansk|Lviv|Makiivka|Mariupol|Mykolaiv|Odesa|Sevastopol|Simferopol|Vinnitsa|Zaporizhzhya|Ukraine|Kyiv|Kiev)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'United Arab Emirates': re.compile(r'\b(Ajman|Al-Ain|United Arab Emirates|Abu Zaby|Abu Dhabi|Ash-Shariqah|Sharjah|Dubayy|Dubai)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'United Republic of Tanzania': re.compile(r'\b(Arusha|Dar es Salaam|Mbeya|Morogoro|Mwanza|Songea|Zanzibar|United Republic of Tanzania)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Uruguay': re.compile(r'\b(Montevideo|Uruguay)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Uzbekistan': re.compile(r'\b(Andizhan|Namangan|Nukus|Samarkand|Tashkent|Uzbekistan)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Viet Nam': re.compile(r'\b(Bien Hoa|Can Tho|Da Nang|Hà Noi|Hai Phòng|Hue|Long Xuyen|Nha Trang|Thu Dau Mot|Vungtau|Vietnam|Viet Nam|Thành Pho Ho Chí Minh|Ho Chi Minh City)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Yemen': re.compile(r"\b(Al-Hudaydah|Al-Mukalla|Dhamar|Ibb|Sana'a'|Ta'izz|Yemen|Adan|Aden)n?\b",
#  re.IGNORECASE|re.UNICODE),
#  'Zambia': re.compile(r'\b(Kitwe|Lusaka|Ndola|Zambia)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Zimbabwe': re.compile(r'\b(Bulawayo|Chitungwiza|Harare|Zimbabwe)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Albania': re.compile(r'\b(Albania|Tiranë|Tirana)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Austria': re.compile(r'\b(Austria|Wien|Vienna)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Bahrain': re.compile(r'\b(Bahrain|Al-Manamah|Manama)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Cambodia': re.compile(r'\b(Cambodia|Phnum Pénh|Phnom Penh)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Denmark': re.compile(r'\b(Denmark|København|Copenhagen)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Guatemala': re.compile(r'\b(Guatemala|Ciudad de Guatemala|Guatemala City)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Kuwait': re.compile(r'\b(Kuwait|Al Kuwayt|Kuwait City)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Lebanon': re.compile(r'\b(Lebanon|Bayrut|Beirut)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Oman': re.compile(r'\b(Oman|Masqat|Muscat|Salahah|Salalah)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Panama': re.compile(r'\b(Panama|Ciudad de Panamá|Panama City)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'Serbia': re.compile(r'\b(Serbia|Beograd|Belgrade)n?\b',
#  re.IGNORECASE|re.UNICODE),
#  'State of Palestine': re.compile(r'\b(State of Palestine|Gaza|Ash Shati Camp)n?\b',
#  re.IGNORECASE|re.UNICODE)}

# %%
source_country = {}
for fi in tqdm(file_info):
    if fi.site not in source_country:
        source_country[fi.site] = Counter()
        
    for country, regex in country_regex.items():
        if regex.search(fi.text + " " + fi.title):
            source_country[fi.site][country] += 1
# Out:
# HBox(children=(FloatProgress(value=0.0, max=394408.0), HTML(value='')))

# %%
country_list = list(country_regex.keys())
source_country_frequency = {}
for source, countries in source_country.items():
    total = sum(countries.values())
    source_country_frequency[source] = [countries[c] / total if total > 0 else 0 for c in country_list]

# %%
for source, freqs in list(source_country_frequency.items())[:50]:
    print(source)
    countries_by_freq = list(zip(country_list, freqs))
    countries_by_freq.sort(key=lambda x: x[1], reverse=True)
    for c, f in countries_by_freq[:5]:
        print(f"\t{c}: {f}")

# %%
with open("data/source_country.tsv", "w") as f:
    for source, freqs in source_country_frequency.items():
        countries_by_freq = list(zip(country_list, freqs))
        countries_by_freq.sort(key=lambda x: x[1], reverse=True)
        top_country = countries_by_freq[0][0]
        f.write(f"{source}\t{top_country}\n")

# %%
with open("data/source_country_frequencies.json", "w") as f:
    json.dump([source_country_frequency, country_list], f, indent=2)
